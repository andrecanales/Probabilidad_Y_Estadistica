# %% [markdown]
# <a href="https://colab.research.google.com/github/andrecanales/Probabilidad_Y_Estadistica/blob/main/Practica_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Histogramas

# %%
import random
from statistics import *

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [64.03, 62.23, 81.07, 73.05, 79.55, 76.58, 83.7, 50.35, 81.58, 83.24, 70.31, 78.85, 68.85, 85.84, 53.71, 85.61, 77.64, 70.33, 53.19, 95.57, 84.96, 62.02, 93.83, 90.28, 70.96, 74.24, 83.85, 52.35, 85.33, 63.64, 91.77, 70.16, 73.74, 92.03, 89.94, 60.44, 85.5, 90.06, 96.96, 65.97, 82.8, 89.38, 55.43, 99.78, 52.03, 61.66, 79.78, 56.05, 77.77, 56.84, 59.97, 97.53, 88.6, 52.61, 70.52, 97.7, 62.89, 54.8, 60.06, 85.19, 93.99, 85.24, 80.97, 87.12, 79.31, 87.04, 55.61, 59.92, 87.93, 58.75, 89.09, 76.13, 83.6, 70.02, 85.73, 62.57, 88.08, 93.36, 69.45, 56.77, 69.62, 60.38, 51.27, 94.94, 88.14, 93.28, 82.61, 84.18, 71.75, 78.27, 58.2, 95.56, 85.2, 62.01, 96.66, 57.99, 74.25, 51.26, 60.95, 54.38]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio2 = round(random.uniform(50, 100), 2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [85.76, 96.62, 60.27, 93.88, 99.9, 62.12, 71.06, 71.1, 51.4, 98.71, 99.48, 80.29, 53.56, 87.97, 58.4, 56.0, 95.46, 90.82, 81.95, 82.62, 50.21, 52.41, 85.14, 82.81, 86.84, 65.44, 69.89, 99.03, 61.36, 69.35, 79.08, 90.2, 71.08, 91.53, 79.63, 96.69, 78.53, 83.66, 94.5, 99.5, 76.88, 61.69, 99.96, 74.35, 52.3, 79.44, 63.61, 53.03, 74.56, 98.23, 97.79, 81.24, 86.74, 69.16, 93.24, 76.25, 65.33, 67.67, 69.5, 68.57, 52.62, 87.04, 99.02, 74.69, 79.48, 51.21, 67.74, 59.65, 68.69, 58.61, 57.73, 51.65, 82.9, 78.72, 87.23, 90.02, 88.69, 94.7, 86.05, 75.08, 74.55, 62.79, 82.82, 58.21, 59.24, 92.6, 83.68, 86.56, 85.53, 63.07, 81.26, 82.73, 96.12, 82.76, 87.61, 62.0, 73.98, 82.05, 82.16, 50.4]

# %%
import matplotlib.pyplot as plt
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 1')

# %%
import matplotlib.pyplot as plt
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 2')

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("Valores de la fabrica 1")
print("Media: ", media1)
print("Mediana: ", mediana1)
print("Moda: ", moda1)
# Out:
# Valores de la fabrica 1
# Media:  75.1628
# Mediana:  77.705
# Moda:  64.03

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("Valores de la fabrica 2")
print("Media: ", media2)
print("Mediana: ", mediana2)
print("Moda: ", moda2)
# Out:
# Valores de la fabrica 2
# Media:  76.9543
# Mediana:  79.46000000000001
# Moda:  85.76

# %%
fig, (ax1, ax2) = plt.subplots(nrows =1, ncols =2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

plt.hist(fabrica1, bins=10, alpha=0.4, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('Produccion diaria de la fabrica 1')
plt.legend()
plt.show()

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

plt.hist(fabrica2, bins=20, alpha=0.4, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('Produccion diaria de la fabrica 2')
plt.legend()
plt.show()

# %% [markdown]
# ##Maximo, minimo y rango

# %%
maximo = max(fabrica1)
minimo = min(fabrica1)
rango = maximo - minimo
media = mean (fabrica1)
mediana = median(fabrica1)
moda = mode(fabrica1)

print("Estadistica descriptica de la fabrica 1: " "Media =", media,
      "\n Mediana = ", mediana, "\n Moda = ", moda, "\n Maximo =", maximo,
      "\n Minimo = ", minimo, "\n Rango =", rango)
# Out:
# Estadistica descriptica de la fabrica 1: Media = 75.1628
#  Mediana =  77.705
#  Moda =  64.03
#  Maximo = 99.78
#  Minimo =  50.35
#  Rango = 49.43

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean (fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("Estadistica descriptica de la fabrica 2: " "Media =", media2,
      "\n Mediana = ", mediana2, "\n Moda = ", moda2, "\n Maximo =", maximo2,
      "\n Minimo = ", minimo2, "\n Rango =", rango2)
# Out:
# Estadistica descriptica de la fabrica 2: Media = 76.9543
#  Mediana =  79.46000000000001
#  Moda =  85.76
#  Maximo = 99.96
#  Minimo =  50.21
#  Rango = 49.74999999999999

# %% [markdown]
# ##Dispercion de datos

# %%
desviacion_estandar_fabrica1 = stdev(fabrica1)
print("La desviacion estandar de la fabrica 1 es: ", desviacion_estandar_fabrica1)
# Out:
# La desviacion estandar de la fabrica 1 es:  14.236651169613326

# %%
desviacion_estandar_fabrica2 = stdev(fabrica2)
print("La desviacion estandar de la fabrica 2 es: ", desviacion_estandar_fabrica2)
# Out:
# La desviacion estandar de la fabrica 2 es:  14.613300379787551

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

plt.figure(figsize =(10,8))
plt.hist(fabrica1, bins=10, alpha=0.4, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media ={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana ={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda ={moda1:.2f}')

plt.axvline(media1 - desviacion_estandar_fabrica1, color='black',
            linestyle='dashed', linewidth=2, label=f'Des. Estandar ={desviacion_estandar_fabrica1:.2f}')

plt.axvline(media1 + desviacion_estandar_fabrica1, color='black',
            linestyle='dashed', linewidth=2)

plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('Produccion diaria de la fabrica 1')
plt.legend()
plt.show()

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

plt.figure(figsize =(10,8))
plt.hist(fabrica2, bins=10, alpha=0.4, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media ={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana ={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda ={moda2:.2f}')

plt.axvline(media2 - desviacion_estandar_fabrica1, color='black',
            linestyle='dashed', linewidth=2, label=f'Des. Estandar ={desviacion_estandar_fabrica2:.2f}')

plt.axvline(media2 + desviacion_estandar_fabrica1, color='black',
            linestyle='dashed', linewidth=2)

plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('Produccion diaria de la fabrica 2')
plt.legend()
plt.show()
