# %% [markdown]
# <a href="https://colab.research.google.com/github/andrecanales/Probabilidad_Y_Estadistica/blob/main/Practica_4%2C5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Histogramas

# %%
import random
from statistics import *

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [73.71, 65.75, 78.69, 91.28, 87.56, 88.73, 90.41, 52.83, 59.99, 50.25, 68.04, 79.4, 84.72, 52.86, 88.66, 98.94, 59.5, 90.31, 97.04, 56.27, 84.48, 59.7, 64.69, 79.71, 58.01, 97.43, 66.86, 94.64, 50.65, 94.3, 81.79, 83.16, 78.14, 53.11, 95.1, 69.98, 92.28, 72.54, 55.59, 98.07, 83.3, 66.03, 63.23, 66.87, 87.04, 91.45, 88.22, 56.74, 68.85, 62.2, 93.03, 85.03, 84.63, 62.11, 84.14, 69.64, 60.31, 57.53, 95.63, 70.06, 58.71, 71.43, 75.38, 77.14, 74.46, 80.13, 81.5, 69.8, 98.76, 82.01, 87.86, 62.8, 96.05, 57.16, 69.81, 82.46, 86.02, 76.69, 99.41, 61.68, 87.32, 76.39, 76.55, 70.14, 59.7, 86.68, 79.88, 78.87, 67.38, 72.49, 69.65, 91.46, 80.92, 95.99, 87.66, 66.07, 79.46, 50.79, 97.14, 75.46]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio2 = round(random.uniform(50, 100), 2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [56.43, 98.23, 58.48, 52.69, 98.43, 95.31, 67.61, 77.48, 71.1, 73.85, 52.83, 54.15, 52.85, 77.04, 98.69, 97.23, 96.52, 75.14, 89.42, 69.69, 59.31, 82.78, 64.61, 59.34, 99.83, 74.21, 98.41, 57.1, 59.05, 55.62, 56.62, 99.99, 77.81, 80.23, 55.93, 71.81, 86.3, 50.0, 65.96, 53.54, 69.94, 93.22, 55.82, 94.98, 69.61, 64.01, 87.33, 83.54, 81.78, 99.51, 72.28, 70.19, 89.59, 60.3, 95.25, 67.1, 52.22, 90.49, 96.23, 87.51, 90.61, 61.51, 96.57, 72.04, 69.91, 90.2, 61.96, 98.16, 81.34, 65.08, 72.55, 54.94, 78.69, 90.16, 85.8, 55.4, 63.93, 98.85, 84.76, 92.29, 63.2, 60.87, 53.1, 79.93, 94.87, 54.68, 54.64, 79.48, 97.31, 71.08, 98.94, 56.71, 61.92, 57.19, 69.38, 87.0, 53.04, 59.47, 62.37, 51.73]

# %%
import matplotlib.pyplot as plt
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 1')

# %%
import matplotlib.pyplot as plt
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 2')

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("Valores de la fabrica 1")
print("Media: ", media1)
print("Mediana: ", mediana1)
print("Moda: ", moda1)
# Out:
# Valores de la fabrica 1
# Media:  76.4047
# Mediana:  77.64
# Moda:  59.7

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("Valores de la fabrica 2")
print("Media: ", media2)
print("Mediana: ", mediana2)
print("Moda: ", moda2)
# Out:
# Valores de la fabrica 2
# Media:  74.3418
# Mediana:  71.92500000000001
# Moda:  56.43

# %%
fig, (ax1, ax2) = plt.subplots(nrows =1, ncols =2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

plt.hist(fabrica1, bins=10, alpha=0.4, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('Produccion diaria de la fabrica 1')
plt.legend()
plt.show()

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

plt.hist(fabrica2, bins=20, alpha=0.4, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('Produccion diaria de la fabrica 2')
plt.legend()
plt.show()

# %% [markdown]
# ##Maximo, minimo y rango

# %%
maximo = max(fabrica1)
minimo = min(fabrica1)
rango = maximo - minimo
media = mean (fabrica1)
mediana = median(fabrica1)
moda = mode(fabrica1)

print("Estadistica descriptica de la fabrica 1: " "Media =", media,
      "\n Mediana = ", mediana, "\n Moda = ", moda, "\n Maximo =", maximo,
      "\n Minimo = ", minimo, "\n Rango =", rango)
# Out:
# Estadistica descriptica de la fabrica 1: Media = 76.4047
#  Mediana =  77.64
#  Moda =  59.7
#  Maximo = 99.41
#  Minimo =  50.25
#  Rango = 49.16

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean (fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("Estadistica descriptica de la fabrica 2: " "Media =", media2,
      "\n Mediana = ", mediana2, "\n Moda = ", moda2, "\n Maximo =", maximo2,
      "\n Minimo = ", minimo2, "\n Rango =", rango2)
# Out:
# Estadistica descriptica de la fabrica 2: Media = 74.3418
#  Mediana =  71.92500000000001
#  Moda =  56.43
#  Maximo = 99.99
#  Minimo =  50.0
#  Rango = 49.989999999999995

# %% [markdown]
# ##Dispercion de datos

# %%
desviacion_estandar_fabrica1 = stdev(fabrica1)
print("La desviacion estandar de la fabrica 1 es: ", desviacion_estandar_fabrica1)
# Out:
# La desviacion estandar de la fabrica 1 es:  13.769984812165651

# %%
desviacion_estandar_fabrica2 = stdev(fabrica2)
print("La desviacion estandar de la fabrica 2 es: ", desviacion_estandar_fabrica2)
# Out:
# La desviacion estandar de la fabrica 2 es:  16.0637299202114

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

plt.figure(figsize =(10,8))
plt.hist(fabrica1, bins=10, alpha=0.4, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media ={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana ={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda ={moda1:.2f}')

plt.axvline(media1 - desviacion_estandar_fabrica1, color='black',
            linestyle='dashed', linewidth=2, label=f'Des. Estandar ={desviacion_estandar_fabrica1:.2f}')

plt.axvline(media1 + desviacion_estandar_fabrica1, color='black',
            linestyle='dashed', linewidth=2)

plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('Produccion diaria de la fabrica 1')
plt.legend()
plt.show()

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

plt.figure(figsize =(10,8))
plt.hist(fabrica2, bins=10, alpha=0.4, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media ={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana ={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda ={moda2:.2f}')

plt.axvline(media2 - desviacion_estandar_fabrica1, color='black',
            linestyle='dashed', linewidth=2, label=f'Des. Estandar ={desviacion_estandar_fabrica2:.2f}')

plt.axvline(media2 + desviacion_estandar_fabrica1, color='black',
            linestyle='dashed', linewidth=2)

plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('Produccion diaria de la fabrica 2')
plt.legend()
plt.show()

# %% [markdown]
# ##Tablas de frecuencia

# %%
edades = []

for i in range(100):
  numero_aleatorio3 = random.randint(18, 70)
  edades.append(numero_aleatorio3)
print(edades)
# Out:
# [18, 65, 67, 66, 55, 32, 21, 20, 57, 60, 34, 39, 41, 19, 38, 30, 56, 43, 37, 37, 27, 31, 18, 42, 26, 25, 20, 50, 44, 54, 19, 22, 62, 50, 33, 54, 48, 48, 24, 65, 21, 21, 41, 29, 57, 50, 58, 39, 60, 40, 46, 63, 70, 26, 22, 63, 50, 55, 22, 42, 33, 26, 38, 33, 55, 41, 47, 61, 64, 50, 50, 60, 23, 52, 64, 27, 56, 29, 21, 38, 64, 54, 38, 18, 34, 33, 35, 25, 29, 60, 19, 62, 66, 34, 38, 44, 40, 26, 48, 56]

# %%
import pandas as pd

# %%
df_edades = pd.DataFrame(edades, columns=["Edad"])
df_edades
# Out:
#     Edad
# 0     18
# 1     65
# 2     67
# 3     66
# 4     55
# ..   ...
# 95    44
# 96    40
# 97    26
# 98    48
# 99    56
#
# [100 rows x 1 columns]

# %%
tabla_frecuencias = df_edades["Edad"].value_counts().reset_index()
tabla_frecuencias.columns = ["Edad", "Frecuencia"]
tabla_frecuencias = tabla_frecuencias.sort_values(by = "Edad")
tabla_frecuencias
# Out:
#     Edad  Frecuencia
# 13    18           3
# 6     19           3
# 20    20           2
# 4     21           4
# 10    22           3
# 30    23           1
# 39    24           1
# 24    25           2
# 2     26           4
# 27    27           2
# 8     29           3
# 40    30           1
# 41    31           1
# 36    32           1
# 3     33           4
# 15    34           3
# 43    35           1
# 28    37           2
# 1     38           5
# 29    39           2
# 17    40           2
# 14    41           3
# 26    42           2
# 42    43           1
# 23    44           2
# 37    46           1
# 34    47           1
# 9     48           3
# 0     50           6
# 33    52           1
# 11    54           3
# 16    55           3
# 12    56           3
# 21    57           2
# 38    58           1
# 5     60           4
# 32    61           1
# 19    62           2
# 22    63           2
# 7     64           3
# 25    65           2
# 18    66           2
# 31    67           1
# 35    70           1

# %%
tabla_frecuencias["Frec. Relativas"] = tabla_frecuencias["Frecuencia"] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativas
# 13    18           3             0.03
# 6     19           3             0.03
# 20    20           2             0.02
# 4     21           4             0.04
# 10    22           3             0.03
# 30    23           1             0.01
# 39    24           1             0.01
# 24    25           2             0.02
# 2     26           4             0.04
# 27    27           2             0.02
# 8     29           3             0.03
# 40    30           1             0.01
# 41    31           1             0.01
# 36    32           1             0.01
# 3     33           4             0.04
# 15    34           3             0.03
# 43    35           1             0.01
# 28    37           2             0.02
# 1     38           5             0.05
# 29    39           2             0.02
# 17    40           2             0.02
# 14    41           3             0.03
# 26    42           2             0.02
# 42    43           1             0.01
# 23    44           2             0.02
# 37    46           1             0.01
# 34    47           1             0.01
# 9     48           3             0.03
# 0     50           6             0.06
# 33    52           1             0.01
# 11    54           3             0.03
# 16    55           3             0.03
# 12    56           3             0.03
# 21    57           2             0.02
# 38    58           1             0.01
# 5     60           4             0.04
# 32    61           1             0.01
# 19    62           2             0.02
# 22    63           2             0.02
# 7     64           3             0.03
# 25    65           2             0.02
# 18    66           2             0.02
# 31    67           1             0.01
# 35    70           1             0.01

# %%
tabla_frecuencias["Frec. porcentual"] = tabla_frecuencias["Frecuencia"] / 100 *100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativas  Frec. porcentual
# 13    18           3             0.03               3.0
# 6     19           3             0.03               3.0
# 20    20           2             0.02               2.0
# 4     21           4             0.04               4.0
# 10    22           3             0.03               3.0
# 30    23           1             0.01               1.0
# 39    24           1             0.01               1.0
# 24    25           2             0.02               2.0
# 2     26           4             0.04               4.0
# 27    27           2             0.02               2.0
# 8     29           3             0.03               3.0
# 40    30           1             0.01               1.0
# 41    31           1             0.01               1.0
# 36    32           1             0.01               1.0
# 3     33           4             0.04               4.0
# 15    34           3             0.03               3.0
# 43    35           1             0.01               1.0
# 28    37           2             0.02               2.0
# 1     38           5             0.05               5.0
# 29    39           2             0.02               2.0
# 17    40           2             0.02               2.0
# 14    41           3             0.03               3.0
# 26    42           2             0.02               2.0
# 42    43           1             0.01               1.0
# 23    44           2             0.02               2.0
# 37    46           1             0.01               1.0
# 34    47           1             0.01               1.0
# 9     48           3             0.03               3.0
# 0     50           6             0.06               6.0
# 33    52           1             0.01               1.0
# 11    54           3             0.03               3.0
# 16    55           3             0.03               3.0
# 12    56           3             0.03               3.0
# 21    57           2             0.02               2.0
# 38    58           1             0.01               1.0
# 5     60           4             0.04               4.0
# 32    61           1             0.01               1.0
# 19    62           2             0.02               2.0
# 22    63           2             0.02               2.0
# 7     64           3             0.03               3.0
# 25    65           2             0.02               2.0
# 18    66           2             0.02               2.0
# 31    67           1             0.01               1.0
# 35    70           1             0.01               1.0

# %%
tabla_frecuencias["Frec. Acumulada"] = tabla_frecuencias["Frecuencia"].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativas  Frec. porcentual  Frec. Acumulada
# 13    18           3             0.03               3.0                3
# 6     19           3             0.03               3.0                6
# 20    20           2             0.02               2.0                8
# 4     21           4             0.04               4.0               12
# 10    22           3             0.03               3.0               15
# 30    23           1             0.01               1.0               16
# 39    24           1             0.01               1.0               17
# 24    25           2             0.02               2.0               19
# 2     26           4             0.04               4.0               23
# 27    27           2             0.02               2.0               25
# 8     29           3             0.03               3.0               28
# 40    30           1             0.01               1.0               29
# 41    31           1             0.01               1.0               30
# 36    32           1             0.01               1.0               31
# 3     33           4             0.04               4.0               35
# 15    34           3             0.03               3.0               38
# 43    35           1             0.01               1.0               39
# 28    37           2             0.02               2.0               41
# 1     38           5             0.05               5.0               46
# 29    39           2             0.02               2.0               48
# 17    40           2             0.02               2.0               50
# 14    41           3             0.03               3.0               53
# 26    42           2             0.02               2.0               55
# 42    43           1             0.01               1.0               56
# 23    44           2             0.02               2.0               58
# 37    46           1             0.01               1.0               59
# 34    47           1             0.01               1.0               60
# 9     48           3             0.03               3.0               63
# 0     50           6             0.06               6.0               69
# 33    52           1             0.01               1.0               70
# 11    54           3             0.03               3.0               73
# 16    55           3             0.03               3.0               76
# 12    56           3             0.03               3.0               79
# 21    57           2             0.02               2.0               81
# 38    58           1             0.01               1.0               82
# 5     60           4             0.04               4.0               86
# 32    61           1             0.01               1.0               87
# 19    62           2             0.02               2.0               89
# 22    63           2             0.02               2.0               91
# 7     64           3             0.03               3.0               94
# 25    65           2             0.02               2.0               96
# 18    66           2             0.02               2.0               98
# 31    67           1             0.01               1.0               99
# 35    70           1             0.01               1.0              100

# %% [markdown]
# ##Regla dde Strunger
#
# $
# c = 1 + Log_2(N)
# $

# %%
import math

# %%
print(edades)
# Out:
# [18, 65, 67, 66, 55, 32, 21, 20, 57, 60, 34, 39, 41, 19, 38, 30, 56, 43, 37, 37, 27, 31, 18, 42, 26, 25, 20, 50, 44, 54, 19, 22, 62, 50, 33, 54, 48, 48, 24, 65, 21, 21, 41, 29, 57, 50, 58, 39, 60, 40, 46, 63, 70, 26, 22, 63, 50, 55, 22, 42, 33, 26, 38, 33, 55, 41, 47, 61, 64, 50, 50, 60, 23, 52, 64, 27, 56, 29, 21, 38, 64, 54, 38, 18, 34, 33, 35, 25, 29, 60, 19, 62, 66, 34, 38, 44, 40, 26, 48, 56]

# %%
plt.hist(edades, alpha=0.5, rwidth = 0.90)
plt.title("Histograma de edades basado en valores estandar de matplotlib")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en valores estandar de matplotlib')

# %%
df_edades_sturges = pd.DataFrame({"Edad": edades})
df_edades_sturges
# Out:
#     Edad
# 0     18
# 1     65
# 2     67
# 3     66
# 4     55
# ..   ...
# 95    44
# 96    40
# 97    26
# 98    48
# 99    56
#
# [100 rows x 1 columns]

# %%
n = len(edades)
k = int(1 + math.log2(n))

print("Valor de n:", n, "\nValor de K o numero de intervalos o clases :", k)
# Out:
# Valor de n: 100
# Valor de K o numero de intervalos o clases : 7

# %%
tabla_frec_sturges = pd.cut(df_edades_sturges["Edad"], bins = k).value_counts().reset_index()
tabla_frec_sturges
# Out:
#               index  Edad
# 0  (17.948, 25.429]    19
# 1  (32.857, 40.286]    19
# 2  (47.714, 55.143]    16
# 3  (55.143, 62.571]    13
# 4  (25.429, 32.857]    12
# 5    (62.571, 70.0]    11
# 6  (40.286, 47.714]    10

# %%
tabla_frec_sturges.columns = ["Clase", "Frecuencia"]
tabla_frec_sturges
# Out:
#               Clase  Frecuencia
# 0  (17.948, 25.429]          19
# 1  (32.857, 40.286]          19
# 2  (47.714, 55.143]          16
# 3  (55.143, 62.571]          13
# 4  (25.429, 32.857]          12
# 5    (62.571, 70.0]          11
# 6  (40.286, 47.714]          10

# %%
tabla_frec_sturges = tabla_frec_sturges.sort_values(by ="Clase")
tabla_frec_sturges
# Out:
#               Clase  Frecuencia
# 0  (17.948, 25.429]          19
# 4  (25.429, 32.857]          12
# 1  (32.857, 40.286]          19
# 6  (40.286, 47.714]          10
# 2  (47.714, 55.143]          16
# 3  (55.143, 62.571]          13
# 5    (62.571, 70.0]          11

# %%
tabla_frec_sturges["Frec. relativa"] = tabla_frec_sturges["Frecuencia"] / n
tabla_frec_sturges["Frec. porcentual"] = tabla_frec_sturges["Frecuencia"] / n * 100
tabla_frec_sturges["Frec. acumulada"] = tabla_frec_sturges["Frecuencia"].cumsum()

tabla_frec_sturges
# Out:
#               Clase  Frecuencia  Frec. relativa  Frec. porcentual  \
# 0  (17.948, 25.429]          19            0.19              19.0
# 4  (25.429, 32.857]          12            0.12              12.0
# 1  (32.857, 40.286]          19            0.19              19.0
# 6  (40.286, 47.714]          10            0.10              10.0
# 2  (47.714, 55.143]          16            0.16              16.0
# 3  (55.143, 62.571]          13            0.13              13.0
# 5    (62.571, 70.0]          11            0.11              11.0
#
#    Frec. acumulada
# 0               19
# 4               31
# 1               50
# 6               60
# 2               76
# 3               89
# 5              100

# %%
plt.hist(df_edades_sturges["Edad"], bins=k, alpha=0.5, rwidth = 0.90)
plt.title("Histograma de edades basado en la regla de Sturges")
plt.xlabel("Edades")
plt.ylabel("frecuencia")
# Out:
# Text(0, 0.5, 'frecuencia')
