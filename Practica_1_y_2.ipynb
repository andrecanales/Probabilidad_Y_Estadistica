# %% [markdown]
# <a href="https://colab.research.google.com/github/andrecanales/Probabilidad_Y_Estadistica/blob/main/Practica_1_y_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Histogramas

# %%
import random
from statistics import *

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [58.43, 73.82, 91.77, 51.38, 52.02, 69.21, 73.24, 69.61, 86.32, 89.75, 67.36, 99.48, 51.22, 89.3, 78.06, 69.0, 60.33, 72.36, 68.53, 56.14, 61.87, 62.12, 57.44, 88.02, 91.17, 87.29, 86.48, 98.02, 92.54, 92.53, 69.71, 51.9, 55.89, 56.39, 90.1, 76.94, 60.71, 62.86, 90.94, 75.01, 51.57, 89.89, 97.26, 91.95, 88.88, 52.55, 55.96, 84.82, 69.88, 89.51, 91.64, 92.36, 75.6, 75.64, 81.19, 64.17, 61.49, 74.98, 63.27, 86.91, 83.84, 94.92, 87.49, 56.93, 97.67, 92.67, 81.94, 89.15, 77.46, 94.79, 99.4, 98.4, 52.89, 95.49, 77.85, 88.83, 77.16, 93.51, 77.82, 78.08, 76.33, 59.9, 84.72, 82.53, 64.04, 96.71, 57.51, 94.57, 53.63, 54.78, 56.52, 54.84, 74.5, 73.05, 87.47, 61.58, 54.96, 77.01, 67.13, 72.31]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio2 = round(random.uniform(50, 100), 2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [62.17, 50.78, 60.31, 76.17, 95.04, 97.48, 52.97, 62.36, 96.98, 55.41, 52.82, 73.39, 91.57, 98.71, 91.35, 72.66, 56.64, 92.72, 50.06, 56.64, 67.25, 71.49, 68.99, 70.64, 58.94, 63.02, 88.21, 70.26, 52.45, 70.41, 51.12, 52.9, 69.84, 54.73, 87.74, 95.14, 69.44, 52.33, 71.65, 56.38, 60.62, 94.25, 64.42, 87.15, 65.81, 53.18, 86.83, 91.79, 93.2, 82.73, 96.58, 87.16, 80.26, 61.03, 68.16, 52.67, 72.01, 95.43, 61.07, 50.93, 85.59, 80.04, 94.94, 99.75, 77.66, 70.31, 82.21, 99.2, 50.29, 61.39, 64.11, 50.7, 51.85, 89.85, 63.97, 72.46, 52.05, 87.82, 58.87, 80.56, 69.64, 87.66, 92.69, 63.59, 87.13, 95.17, 55.28, 92.94, 99.41, 71.21, 76.55, 51.4, 73.7, 78.98, 91.42, 84.63, 61.81, 59.62, 97.89, 88.41]

# %%
import matplotlib.pyplot as plt
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 1')

# %%
import matplotlib.pyplot as plt
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 2')

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("Valores de la fabrica 1")
print("Media: ", media1)
print("Mediana: ", mediana1)
print("Moda: ", moda1)
# Out:
# Valores de la fabrica 1
# Media:  75.7516
# Mediana:  76.63499999999999
# Moda:  58.43

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("Valores de la fabrica 2")
print("Media: ", media2)
print("Mediana: ", mediana2)
print("Moda: ", moda2)
# Out:
# Valores de la fabrica 2
# Media:  73.4719
# Mediana:  71.35
# Moda:  56.64

# %%
fig, (ax1, ax2) = plt.subplots(nrows =1, ncols =2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

plt.hist(fabrica1, bins=10, alpha=0.4, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('Produccion diaria de la fabrica 1')
plt.legend()
plt.show()

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

plt.hist(fabrica2, bins=20, alpha=0.4, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('Produccion diaria de la fabrica 2')
plt.legend()
plt.show()
