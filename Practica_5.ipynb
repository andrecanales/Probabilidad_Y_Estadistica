# %% [markdown]
# <a href="https://colab.research.google.com/github/andrecanales/Probabilidad_Y_Estadistica/blob/main/Practica_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Histogramas

# %%
import random
from statistics import *

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [91.31, 98.73, 73.01, 53.47, 78.47, 54.08, 54.52, 79.6, 87.08, 58.78, 80.35, 52.63, 61.47, 97.28, 52.95, 62.43, 82.84, 93.14, 55.86, 84.0, 87.9, 71.53, 84.29, 73.87, 50.78, 97.69, 60.56, 50.1, 65.93, 76.08, 66.05, 89.13, 57.38, 90.85, 76.32, 81.01, 82.17, 94.13, 84.01, 98.93, 98.71, 61.82, 60.53, 69.46, 56.42, 91.46, 79.87, 74.41, 86.44, 91.61, 92.86, 87.41, 95.85, 70.31, 84.54, 91.44, 96.68, 51.55, 94.87, 85.87, 65.64, 85.07, 79.67, 59.34, 51.58, 75.1, 92.29, 63.96, 64.77, 84.83, 66.27, 51.01, 65.52, 68.67, 61.41, 79.1, 85.1, 75.9, 81.07, 65.27, 62.34, 94.59, 94.24, 89.95, 70.72, 91.16, 89.78, 79.42, 52.37, 92.54, 61.44, 81.54, 56.63, 57.24, 78.0, 78.38, 72.97, 82.38, 55.73, 53.85]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio2 = round(random.uniform(50, 100), 2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [89.12, 83.38, 77.38, 69.21, 86.51, 65.82, 96.55, 70.64, 98.39, 80.95, 91.67, 85.42, 80.43, 73.62, 96.77, 63.67, 80.15, 83.69, 67.96, 50.05, 89.92, 91.14, 65.18, 77.07, 50.18, 61.08, 94.16, 78.46, 97.22, 79.7, 77.31, 72.52, 91.55, 59.34, 75.61, 71.7, 80.51, 53.33, 87.16, 91.59, 78.28, 84.72, 63.06, 72.6, 51.62, 64.02, 71.06, 65.77, 79.45, 76.43, 52.81, 97.05, 74.64, 76.64, 57.7, 57.93, 51.95, 93.68, 72.83, 79.1, 62.33, 59.57, 95.6, 75.98, 99.13, 96.01, 91.41, 74.3, 57.9, 92.32, 71.63, 68.15, 77.9, 64.36, 89.91, 87.0, 92.67, 85.01, 69.31, 57.74, 57.79, 95.05, 82.15, 66.77, 72.77, 54.13, 79.7, 83.37, 78.95, 93.37, 71.22, 67.54, 51.88, 93.76, 66.44, 99.7, 50.21, 84.89, 53.65, 67.86]

# %%
import matplotlib.pyplot as plt
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 1')

# %%
import matplotlib.pyplot as plt
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 2')

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("Valores de la fabrica 1")
print("Media: ", media1)
print("Mediana: ", mediana1)
print("Moda: ", moda1)
# Out:
# Valores de la fabrica 1
# Media:  75.2966
# Mediana:  78.19
# Moda:  91.31

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("Valores de la fabrica 2")
print("Media: ", media2)
print("Mediana: ", mediana2)
print("Moda: ", moda2)
# Out:
# Valores de la fabrica 2
# Media:  75.9688
# Mediana:  76.85499999999999
# Moda:  79.7

# %%
fig, (ax1, ax2) = plt.subplots(nrows =1, ncols =2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

plt.hist(fabrica1, bins=10, alpha=0.4, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('Produccion diaria de la fabrica 1')
plt.legend()
plt.show()

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

plt.hist(fabrica2, bins=20, alpha=0.4, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('Produccion diaria de la fabrica 2')
plt.legend()
plt.show()

# %% [markdown]
# ##Maximo, minimo y rango

# %%
maximo = max(fabrica1)
minimo = min(fabrica1)
rango = maximo - minimo
media = mean (fabrica1)
mediana = median(fabrica1)
moda = mode(fabrica1)

print("Estadistica descriptica de la fabrica 1: " "Media =", media,
      "\n Mediana = ", mediana, "\n Moda = ", moda, "\n Maximo =", maximo,
      "\n Minimo = ", minimo, "\n Rango =", rango)
# Out:
# Estadistica descriptica de la fabrica 1: Media = 75.2966
#  Mediana =  78.19
#  Moda =  91.31
#  Maximo = 98.93
#  Minimo =  50.1
#  Rango = 48.830000000000005

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean (fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("Estadistica descriptica de la fabrica 2: " "Media =", media2,
      "\n Mediana = ", mediana2, "\n Moda = ", moda2, "\n Maximo =", maximo2,
      "\n Minimo = ", minimo2, "\n Rango =", rango2)
# Out:
# Estadistica descriptica de la fabrica 2: Media = 75.9688
#  Mediana =  76.85499999999999
#  Moda =  79.7
#  Maximo = 99.7
#  Minimo =  50.05
#  Rango = 49.650000000000006

# %% [markdown]
# ##Dispercion de datos

# %%
desviacion_estandar_fabrica1 = stdev(fabrica1)
print("La desviacion estandar de la fabrica 1 es: ", desviacion_estandar_fabrica1)
# Out:
# La desviacion estandar de la fabrica 1 es:  14.71985947863318

# %%
desviacion_estandar_fabrica2 = stdev(fabrica2)
print("La desviacion estandar de la fabrica 2 es: ", desviacion_estandar_fabrica2)
# Out:
# La desviacion estandar de la fabrica 2 es:  13.898213843526946

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

plt.figure(figsize =(10,8))
plt.hist(fabrica1, bins=10, alpha=0.4, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media ={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana ={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda ={moda1:.2f}')

plt.axvline(media1 - desviacion_estandar_fabrica1, color='black',
            linestyle='dashed', linewidth=2, label=f'Des. Estandar ={desviacion_estandar_fabrica1:.2f}')

plt.axvline(media1 + desviacion_estandar_fabrica1, color='black',
            linestyle='dashed', linewidth=2)

plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('Produccion diaria de la fabrica 1')
plt.legend()
plt.show()

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

plt.figure(figsize =(10,8))
plt.hist(fabrica2, bins=10, alpha=0.4, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media ={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana ={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda ={moda2:.2f}')

plt.axvline(media2 - desviacion_estandar_fabrica1, color='black',
            linestyle='dashed', linewidth=2, label=f'Des. Estandar ={desviacion_estandar_fabrica2:.2f}')

plt.axvline(media2 + desviacion_estandar_fabrica1, color='black',
            linestyle='dashed', linewidth=2)

plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('Produccion diaria de la fabrica 2')
plt.legend()
plt.show()

# %% [markdown]
# ##Tablas de frecuencia

# %%
edades = []

for i in range(100):
  numero_aleatorio3 = random.randint(18, 70)
  edades.append(numero_aleatorio3)
print(edades)
# Out:
# [42, 51, 51, 52, 37, 60, 66, 34, 37, 24, 59, 55, 68, 46, 29, 58, 65, 52, 33, 53, 53, 63, 60, 43, 41, 48, 21, 58, 34, 68, 19, 65, 24, 52, 42, 20, 47, 19, 42, 36, 34, 40, 23, 38, 58, 37, 55, 57, 42, 64, 43, 65, 29, 47, 40, 44, 36, 66, 27, 59, 31, 66, 63, 65, 48, 49, 62, 32, 49, 58, 66, 45, 29, 60, 27, 44, 21, 67, 26, 59, 33, 41, 63, 19, 28, 47, 70, 29, 30, 25, 56, 21, 69, 40, 45, 20, 56, 32, 21, 65]

# %%
import pandas as pd

# %%
df_edades = pd.DataFrame(edades, columns=["Edad"])
df_edades
# Out:
#     Edad
# 0     42
# 1     51
# 2     51
# 3     52
# 4     37
# ..   ...
# 95    20
# 96    56
# 97    32
# 98    21
# 99    65
#
# [100 rows x 1 columns]

# %%
tabla_frecuencias = df_edades["Edad"].value_counts().reset_index()
tabla_frecuencias.columns = ["Edad", "Frecuencia"]
tabla_frecuencias = tabla_frecuencias.sort_values(by = "Edad")
tabla_frecuencias
# Out:
#     Edad  Frecuencia
# 9     19           3
# 23    20           2
# 3     21           4
# 44    23           1
# 26    24           2
# 33    25           1
# 37    26           1
# 19    27           2
# 36    28           1
# 2     29           4
# 34    30           1
# 40    31           1
# 15    32           2
# 28    33           2
# 11    34           3
# 21    36           2
# 13    37           3
# 43    38           1
# 7     40           3
# 29    41           2
# 1     42           4
# 25    43           2
# 20    44           2
# 17    45           2
# 39    46           1
# 6     47           3
# 24    48           2
# 22    49           2
# 16    51           2
# 14    52           3
# 27    53           2
# 31    55           2
# 18    56           2
# 42    57           1
# 5     58           4
# 10    59           3
# 12    60           3
# 38    62           1
# 8     63           3
# 41    64           1
# 0     65           5
# 4     66           4
# 32    67           1
# 30    68           2
# 45    69           1
# 35    70           1

# %%
tabla_frecuencias["Frec. Relativas"] = tabla_frecuencias["Frecuencia"] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativas
# 9     19           3             0.03
# 23    20           2             0.02
# 3     21           4             0.04
# 44    23           1             0.01
# 26    24           2             0.02
# 33    25           1             0.01
# 37    26           1             0.01
# 19    27           2             0.02
# 36    28           1             0.01
# 2     29           4             0.04
# 34    30           1             0.01
# 40    31           1             0.01
# 15    32           2             0.02
# 28    33           2             0.02
# 11    34           3             0.03
# 21    36           2             0.02
# 13    37           3             0.03
# 43    38           1             0.01
# 7     40           3             0.03
# 29    41           2             0.02
# 1     42           4             0.04
# 25    43           2             0.02
# 20    44           2             0.02
# 17    45           2             0.02
# 39    46           1             0.01
# 6     47           3             0.03
# 24    48           2             0.02
# 22    49           2             0.02
# 16    51           2             0.02
# 14    52           3             0.03
# 27    53           2             0.02
# 31    55           2             0.02
# 18    56           2             0.02
# 42    57           1             0.01
# 5     58           4             0.04
# 10    59           3             0.03
# 12    60           3             0.03
# 38    62           1             0.01
# 8     63           3             0.03
# 41    64           1             0.01
# 0     65           5             0.05
# 4     66           4             0.04
# 32    67           1             0.01
# 30    68           2             0.02
# 45    69           1             0.01
# 35    70           1             0.01

# %%
tabla_frecuencias["Frec. porcentual"] = tabla_frecuencias["Frecuencia"] / 100 *100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativas  Frec. porcentual
# 9     19           3             0.03               3.0
# 23    20           2             0.02               2.0
# 3     21           4             0.04               4.0
# 44    23           1             0.01               1.0
# 26    24           2             0.02               2.0
# 33    25           1             0.01               1.0
# 37    26           1             0.01               1.0
# 19    27           2             0.02               2.0
# 36    28           1             0.01               1.0
# 2     29           4             0.04               4.0
# 34    30           1             0.01               1.0
# 40    31           1             0.01               1.0
# 15    32           2             0.02               2.0
# 28    33           2             0.02               2.0
# 11    34           3             0.03               3.0
# 21    36           2             0.02               2.0
# 13    37           3             0.03               3.0
# 43    38           1             0.01               1.0
# 7     40           3             0.03               3.0
# 29    41           2             0.02               2.0
# 1     42           4             0.04               4.0
# 25    43           2             0.02               2.0
# 20    44           2             0.02               2.0
# 17    45           2             0.02               2.0
# 39    46           1             0.01               1.0
# 6     47           3             0.03               3.0
# 24    48           2             0.02               2.0
# 22    49           2             0.02               2.0
# 16    51           2             0.02               2.0
# 14    52           3             0.03               3.0
# 27    53           2             0.02               2.0
# 31    55           2             0.02               2.0
# 18    56           2             0.02               2.0
# 42    57           1             0.01               1.0
# 5     58           4             0.04               4.0
# 10    59           3             0.03               3.0
# 12    60           3             0.03               3.0
# 38    62           1             0.01               1.0
# 8     63           3             0.03               3.0
# 41    64           1             0.01               1.0
# 0     65           5             0.05               5.0
# 4     66           4             0.04               4.0
# 32    67           1             0.01               1.0
# 30    68           2             0.02               2.0
# 45    69           1             0.01               1.0
# 35    70           1             0.01               1.0

# %%
tabla_frecuencias["Frec. Acumulada"] = tabla_frecuencias["Frecuencia"].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativas  Frec. porcentual  Frec. Acumulada
# 9     19           3             0.03               3.0                3
# 23    20           2             0.02               2.0                5
# 3     21           4             0.04               4.0                9
# 44    23           1             0.01               1.0               10
# 26    24           2             0.02               2.0               12
# 33    25           1             0.01               1.0               13
# 37    26           1             0.01               1.0               14
# 19    27           2             0.02               2.0               16
# 36    28           1             0.01               1.0               17
# 2     29           4             0.04               4.0               21
# 34    30           1             0.01               1.0               22
# 40    31           1             0.01               1.0               23
# 15    32           2             0.02               2.0               25
# 28    33           2             0.02               2.0               27
# 11    34           3             0.03               3.0               30
# 21    36           2             0.02               2.0               32
# 13    37           3             0.03               3.0               35
# 43    38           1             0.01               1.0               36
# 7     40           3             0.03               3.0               39
# 29    41           2             0.02               2.0               41
# 1     42           4             0.04               4.0               45
# 25    43           2             0.02               2.0               47
# 20    44           2             0.02               2.0               49
# 17    45           2             0.02               2.0               51
# 39    46           1             0.01               1.0               52
# 6     47           3             0.03               3.0               55
# 24    48           2             0.02               2.0               57
# 22    49           2             0.02               2.0               59
# 16    51           2             0.02               2.0               61
# 14    52           3             0.03               3.0               64
# 27    53           2             0.02               2.0               66
# 31    55           2             0.02               2.0               68
# 18    56           2             0.02               2.0               70
# 42    57           1             0.01               1.0               71
# 5     58           4             0.04               4.0               75
# 10    59           3             0.03               3.0               78
# 12    60           3             0.03               3.0               81
# 38    62           1             0.01               1.0               82
# 8     63           3             0.03               3.0               85
# 41    64           1             0.01               1.0               86
# 0     65           5             0.05               5.0               91
# 4     66           4             0.04               4.0               95
# 32    67           1             0.01               1.0               96
# 30    68           2             0.02               2.0               98
# 45    69           1             0.01               1.0               99
# 35    70           1             0.01               1.0              100

# %% [markdown]
# ##Regla dde Strunger
#
# $
# c = 1 + Log_2(N)
# $

# %%
import math

# %%
print(edades)
# Out:
# [42, 51, 51, 52, 37, 60, 66, 34, 37, 24, 59, 55, 68, 46, 29, 58, 65, 52, 33, 53, 53, 63, 60, 43, 41, 48, 21, 58, 34, 68, 19, 65, 24, 52, 42, 20, 47, 19, 42, 36, 34, 40, 23, 38, 58, 37, 55, 57, 42, 64, 43, 65, 29, 47, 40, 44, 36, 66, 27, 59, 31, 66, 63, 65, 48, 49, 62, 32, 49, 58, 66, 45, 29, 60, 27, 44, 21, 67, 26, 59, 33, 41, 63, 19, 28, 47, 70, 29, 30, 25, 56, 21, 69, 40, 45, 20, 56, 32, 21, 65]

# %%
plt.hist(edades, alpha=0.5, rwidth = 0.90)
plt.title("Histograma de edades basado en valores estandar de matplotlib")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en valores estandar de matplotlib')

# %%
df_edades_sturges = pd.DataFrame({"Edad": edades})
df_edades_sturges
# Out:
#     Edad
# 0     42
# 1     51
# 2     51
# 3     52
# 4     37
# ..   ...
# 95    20
# 96    56
# 97    32
# 98    21
# 99    65
#
# [100 rows x 1 columns]

# %%
n = len(edades)
k = int(1 + math.log2(n))

print("Valor de n:", n, "\nValor de K o numero de intervalos o clases :", k)
# Out:
# Valor de n: 100
# Valor de K o numero de intervalos o clases : 7

# %%
tabla_frec_sturges = pd.cut(df_edades_sturges["Edad"], bins = k).value_counts().reset_index()
tabla_frec_sturges
# Out:
#               index  Edad
# 0  (40.857, 48.143]    18
# 1    (62.714, 70.0]    18
# 2  (18.949, 26.286]    14
# 3  (55.429, 62.714]    14
# 4  (26.286, 33.571]    13
# 5  (33.571, 40.857]    12
# 6  (48.143, 55.429]    11

# %%
tabla_frec_sturges.columns = ["Clase", "Frecuencia"]
tabla_frec_sturges
# Out:
#               Clase  Frecuencia
# 0  (40.857, 48.143]          18
# 1    (62.714, 70.0]          18
# 2  (18.949, 26.286]          14
# 3  (55.429, 62.714]          14
# 4  (26.286, 33.571]          13
# 5  (33.571, 40.857]          12
# 6  (48.143, 55.429]          11

# %%
tabla_frec_sturges = tabla_frec_sturges.sort_values(by ="Clase")
tabla_frec_sturges
# Out:
#               Clase  Frecuencia
# 2  (18.949, 26.286]          14
# 4  (26.286, 33.571]          13
# 5  (33.571, 40.857]          12
# 0  (40.857, 48.143]          18
# 6  (48.143, 55.429]          11
# 3  (55.429, 62.714]          14
# 1    (62.714, 70.0]          18

# %%
tabla_frec_sturges["Frec. relativa"] = tabla_frec_sturges["Frecuencia"] / n
tabla_frec_sturges["Frec. porcentual"] = tabla_frec_sturges["Frecuencia"] / n * 100
tabla_frec_sturges["Frec. acumulada"] = tabla_frec_sturges["Frecuencia"].cumsum()

tabla_frec_sturges
# Out:
#               Clase  Frecuencia  Frec. relativa  Frec. porcentual  \
# 2  (18.949, 26.286]          14            0.14              14.0
# 4  (26.286, 33.571]          13            0.13              13.0
# 5  (33.571, 40.857]          12            0.12              12.0
# 0  (40.857, 48.143]          18            0.18              18.0
# 6  (48.143, 55.429]          11            0.11              11.0
# 3  (55.429, 62.714]          14            0.14              14.0
# 1    (62.714, 70.0]          18            0.18              18.0
#
#    Frec. acumulada
# 2               14
# 4               27
# 5               39
# 0               57
# 6               68
# 3               82
# 1              100

# %%
plt.hist(df_edades_sturges["Edad"], bins=k, alpha=0.5, rwidth = 0.90)
plt.title("Histograma de edades basado en la regla de Sturges")
plt.xlabel("Edades")
plt.ylabel("frecuencia")
# Out:
# Text(0, 0.5, 'frecuencia')

# %%
print(fabrica1)
# Out:
# [91.31, 98.73, 73.01, 53.47, 78.47, 54.08, 54.52, 79.6, 87.08, 58.78, 80.35, 52.63, 61.47, 97.28, 52.95, 62.43, 82.84, 93.14, 55.86, 84.0, 87.9, 71.53, 84.29, 73.87, 50.78, 97.69, 60.56, 50.1, 65.93, 76.08, 66.05, 89.13, 57.38, 90.85, 76.32, 81.01, 82.17, 94.13, 84.01, 98.93, 98.71, 61.82, 60.53, 69.46, 56.42, 91.46, 79.87, 74.41, 86.44, 91.61, 92.86, 87.41, 95.85, 70.31, 84.54, 91.44, 96.68, 51.55, 94.87, 85.87, 65.64, 85.07, 79.67, 59.34, 51.58, 75.1, 92.29, 63.96, 64.77, 84.83, 66.27, 51.01, 65.52, 68.67, 61.41, 79.1, 85.1, 75.9, 81.07, 65.27, 62.34, 94.59, 94.24, 89.95, 70.72, 91.16, 89.78, 79.42, 52.37, 92.54, 61.44, 81.54, 56.63, 57.24, 78.0, 78.38, 72.97, 82.38, 55.73, 53.85]

# %%
plt.boxplot(fabrica1)
plt.title("Produccion de la fabrica 1")
plt.ylabel("Produciion en metros")
plt.show()

# %%
plt.boxplot(fabrica2)
plt.title("Produccion de la fabrica 2")
plt.ylabel("Produciion en metros")
plt.show()

# %% [markdown]
# **Comparacion de la prodciion de la fabrica1 y la fabrica 2 con un diagrama de cajas y bigotes**

# %%
fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (9,4) )
ax1.boxplot(fabrica1, vert = True, patch_artist = True)
ax1.set_title("Produccion de la fabrica 1")
ax2.boxplot(fabrica2, vert = True, patch_artist = True)
ax2.set_title("Produccion de la fabrica 2")
plt.show()

# %%
print(fabrica2)
# Out:
# [89.12, 83.38, 77.38, 69.21, 86.51, 65.82, 96.55, 70.64, 98.39, 80.95, 91.67, 85.42, 80.43, 73.62, 96.77, 63.67, 80.15, 83.69, 67.96, 50.05, 89.92, 91.14, 65.18, 77.07, 50.18, 61.08, 94.16, 78.46, 97.22, 79.7, 77.31, 72.52, 91.55, 59.34, 75.61, 71.7, 80.51, 53.33, 87.16, 91.59, 78.28, 84.72, 63.06, 72.6, 51.62, 64.02, 71.06, 65.77, 79.45, 76.43, 52.81, 97.05, 74.64, 76.64, 57.7, 57.93, 51.95, 93.68, 72.83, 79.1, 62.33, 59.57, 95.6, 75.98, 99.13, 96.01, 91.41, 74.3, 57.9, 92.32, 71.63, 68.15, 77.9, 64.36, 89.91, 87.0, 92.67, 85.01, 69.31, 57.74, 57.79, 95.05, 82.15, 66.77, 72.77, 54.13, 79.7, 83.37, 78.95, 93.37, 71.22, 67.54, 51.88, 93.76, 66.44, 99.7, 50.21, 84.89, 53.65, 67.86]

# %%
fabrica2.append(150)
print (fabrica2)
# Out:
# [89.12, 83.38, 77.38, 69.21, 86.51, 65.82, 96.55, 70.64, 98.39, 80.95, 91.67, 85.42, 80.43, 73.62, 96.77, 63.67, 80.15, 83.69, 67.96, 50.05, 89.92, 91.14, 65.18, 77.07, 50.18, 61.08, 94.16, 78.46, 97.22, 79.7, 77.31, 72.52, 91.55, 59.34, 75.61, 71.7, 80.51, 53.33, 87.16, 91.59, 78.28, 84.72, 63.06, 72.6, 51.62, 64.02, 71.06, 65.77, 79.45, 76.43, 52.81, 97.05, 74.64, 76.64, 57.7, 57.93, 51.95, 93.68, 72.83, 79.1, 62.33, 59.57, 95.6, 75.98, 99.13, 96.01, 91.41, 74.3, 57.9, 92.32, 71.63, 68.15, 77.9, 64.36, 89.91, 87.0, 92.67, 85.01, 69.31, 57.74, 57.79, 95.05, 82.15, 66.77, 72.77, 54.13, 79.7, 83.37, 78.95, 93.37, 71.22, 67.54, 51.88, 93.76, 66.44, 99.7, 50.21, 84.89, 53.65, 67.86, 150, 150]

# %%
plt.boxplot(fabrica2)
plt.title("Produccion de la fabrica 2")
plt.ylabel("Produciion en metros")
plt.show()
